# %%
# %matplotlib inline

import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import csv file as a df
df = pd.read_csv("getTransactionData.csv")
df.head()
# Out:
#    Unnamed: 0   timestamp converted_timestamp_x  \
# 0           0  1620688380   2021-05-10 19:13:00
# 1           1  1620688380   2021-05-10 19:13:00
# 2           2  1620688380   2021-05-10 19:13:00
# 3           3  1620688380   2021-05-10 19:13:00
# 4           4  1620688380   2021-05-10 19:13:00
#
#                                     transaction_hash  value_in_eth  \
# 0  0x8edd40160d02b6a26b8a4f499f0ff831b2d529bb5155...      0.069269
# 1  0x326a36de26cc9475d860c3d64fcc72d77b026c71a06f...      0.143026
# 2  0x2abbc9e9248c87456d502ac734a603630c6360db1380...      1.208415
# 3  0x4a17962fecd576ff4b020e67d8086070d05372d8cde3...      0.013050
# 4  0x9f302274c5b88e6bbe62bc4b31ffb41113d4084ce089...      0.002000
#
#                                  from_address  \
# 0  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 1  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 2  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 3  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 4  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
#
#                                    to_address converted_timestamp_y    close
# 0  0xff717f448ac5fccf200826588d314f2e495d8d9a   2021-05-10 19:13:00  3960.38
# 1  0x184b65151a33dcd424f044474abe8999cb8734ea   2021-05-10 19:13:00  3960.38
# 2  0xb8531efbccb8356623e854f50a0c21f12ea8baef   2021-05-10 19:13:00  3960.38
# 3  0x44fba56884b79bbc53a6ef0ef37b11b6bc2faa39   2021-05-10 19:13:00  3960.38
# 4  0x447950e5052361ccdbfc203665884e4d52ec43b4   2021-05-10 19:13:00  3960.38

# %%
# create new df with source-target columns
new_df = df[['from_address', 'to_address']]
new_df.head()
# Out:
#                                  from_address  \
# 0  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 1  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 2  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 3  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
# 4  0x3f5ce5fbfe3e9af3971dd833d26ba9b5c936f0be
#
#                                    to_address
# 0  0xff717f448ac5fccf200826588d314f2e495d8d9a
# 1  0x184b65151a33dcd424f044474abe8999cb8734ea
# 2  0xb8531efbccb8356623e854f50a0c21f12ea8baef
# 3  0x44fba56884b79bbc53a6ef0ef37b11b6bc2faa39
# 4  0x447950e5052361ccdbfc203665884e4d52ec43b4

# %%
## plot time, ETH price, transaction size of every transaction to see visualize how much a whale is buying/selling relative to price lvl

ax = plt.axes(projection='3d')

# data for 3d line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# data for 3d scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
